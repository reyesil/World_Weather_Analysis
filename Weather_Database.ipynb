# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9028d7a4143ba4309ca193ca03def48c

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 603

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        try:
            city_rain = city_weather["rain"]["1h"]
        except:
            city_rain = 0
            pass
        try:
            city_snow = city_weather["snow"]["1h"]
        except:
            city_snow = 0
            pass
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Rain (inches)": city_rain,
                          "Snow (inches)": city_snow})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ahipara
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | hofn
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | kaitangata
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | trindade
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | itarema
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | hambantota
# Processing Record 14 of Set 1 | sorong
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | guerrero negro
# Processing Record 17 of Set 1 | am timan
# Processing Record 18 of Set 1 | san quintin
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | saint george
# Processing Record 21 of Set 1 | khatanga
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 1 | vestmannaeyjar
# Processing Record 25 of Set 1 | nanortalik
# Processing Record 26 of Set 1 | doaba
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | bambous virieux
# Processing Record 29 of Set 1 | longyearbyen
# Processing Record 30 of Set 1 | pacific grove
# Processing Record 31 of Set 1 | maragheh
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | waddan
# Processing Record 34 of Set 1 | marquette
# Processing Record 35 of Set 1 | provideniya
# Processing Record 36 of Set 1 | glendive
# Processing Record 37 of Set 1 | portland
# Processing Record 38 of Set 1 | aksarka
# Processing Record 39 of Set 1 | port lincoln
# Processing Record 40 of Set 1 | thompson
# Processing Record 41 of Set 1 | arman
# Processing Record 42 of Set 1 | yurgamysh
# Processing Record 43 of Set 1 | bluff
# Processing Record 44 of Set 1 | lagoa
# Processing Record 45 of Set 1 | narsaq
# Processing Record 46 of Set 1 | kieta
# Processing Record 47 of Set 1 | carnarvon
# Processing Record 48 of Set 1 | nikolskoye
# Processing Record 49 of Set 1 | barkhan
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | atoyac
# Processing Record 2 of Set 2 | cape town
# Processing Record 3 of Set 2 | esperance
# Processing Record 4 of Set 2 | beringovskiy
# Processing Record 5 of Set 2 | velikie luki
# City not found. Skipping...
# Processing Record 6 of Set 2 | bari
# Processing Record 7 of Set 2 | georgetown
# Processing Record 8 of Set 2 | xihua
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | havoysund
# Processing Record 12 of Set 2 | almazar
# Processing Record 13 of Set 2 | leningradskiy
# Processing Record 14 of Set 2 | gondanglegi
# Processing Record 15 of Set 2 | victoria
# Processing Record 16 of Set 2 | souillac
# Processing Record 17 of Set 2 | mindelo
# Processing Record 18 of Set 2 | zhongshu
# Processing Record 19 of Set 2 | linguere
# Processing Record 20 of Set 2 | ilulissat
# Processing Record 21 of Set 2 | kodiak
# Processing Record 22 of Set 2 | alice springs
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | bengkulu
# Processing Record 25 of Set 2 | saint-philippe
# Processing Record 26 of Set 2 | la ronge
# Processing Record 27 of Set 2 | mount isa
# Processing Record 28 of Set 2 | arraial do cabo
# Processing Record 29 of Set 2 | uruacu
# Processing Record 30 of Set 2 | mataura
# Processing Record 31 of Set 2 | hilo
# Processing Record 32 of Set 2 | benguela
# Processing Record 33 of Set 2 | te anau
# Processing Record 34 of Set 2 | east london
# Processing Record 35 of Set 2 | klaksvik
# Processing Record 36 of Set 2 | whitehorse
# Processing Record 37 of Set 2 | punta arenas
# Processing Record 38 of Set 2 | goderich
# Processing Record 39 of Set 2 | cartagena del chaira
# Processing Record 40 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 2 | faanui
# Processing Record 42 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 2 | gamba
# Processing Record 45 of Set 2 | tura
# Processing Record 46 of Set 2 | finschhafen
# Processing Record 47 of Set 2 | havre-saint-pierre
# Processing Record 48 of Set 2 | verkhoyansk
# Processing Record 49 of Set 2 | upernavik
# Processing Record 50 of Set 2 | pyshma
# Processing Record 1 of Set 3 | pathein
# Processing Record 2 of Set 3 | storvorde
# Processing Record 3 of Set 3 | puerto ayora
# Processing Record 4 of Set 3 | mumford
# Processing Record 5 of Set 3 | poddorye
# Processing Record 6 of Set 3 | davila
# Processing Record 7 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 3 | yellowknife
# Processing Record 9 of Set 3 | labuan
# Processing Record 10 of Set 3 | ambilobe
# Processing Record 11 of Set 3 | ponta do sol
# Processing Record 12 of Set 3 | pevek
# Processing Record 13 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 3 | beberibe
# Processing Record 15 of Set 3 | batagay
# Processing Record 16 of Set 3 | castro
# Processing Record 17 of Set 3 | ancud
# Processing Record 18 of Set 3 | lasa
# Processing Record 19 of Set 3 | methoni
# Processing Record 20 of Set 3 | abu samrah
# Processing Record 21 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 3 | shimoda
# Processing Record 23 of Set 3 | dudinka
# Processing Record 24 of Set 3 | asau
# Processing Record 25 of Set 3 | severo-kurilsk
# Processing Record 26 of Set 3 | comodoro rivadavia
# Processing Record 27 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 3 | sur
# Processing Record 29 of Set 3 | gat
# Processing Record 30 of Set 3 | olafsvik
# Processing Record 31 of Set 3 | port hawkesbury
# Processing Record 32 of Set 3 | college
# Processing Record 33 of Set 3 | kudahuvadhoo
# Processing Record 34 of Set 3 | bambanglipuro
# Processing Record 35 of Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 36 of Set 3 | ganzhou
# Processing Record 37 of Set 3 | chokurdakh
# Processing Record 38 of Set 3 | airai
# Processing Record 39 of Set 3 | dien bien
# City not found. Skipping...
# Processing Record 40 of Set 3 | newport
# Processing Record 41 of Set 3 | geraldton
# Processing Record 42 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 3 | hithadhoo
# Processing Record 44 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 3 | ulaangom
# Processing Record 46 of Set 3 | ijaki
# City not found. Skipping...
# Processing Record 47 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 3 | port-cartier
# Processing Record 49 of Set 3 | vardo
# Processing Record 50 of Set 3 | adre
# Processing Record 1 of Set 4 | sobolevo
# Processing Record 2 of Set 4 | preobrazheniye
# Processing Record 3 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 4 | qaanaaq
# Processing Record 5 of Set 4 | foumban
# Processing Record 6 of Set 4 | samarai
# Processing Record 7 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 4 | noumea
# Processing Record 9 of Set 4 | bethel
# Processing Record 10 of Set 4 | matara
# Processing Record 11 of Set 4 | brownwood
# Processing Record 12 of Set 4 | takoradi
# Processing Record 13 of Set 4 | norman wells
# Processing Record 14 of Set 4 | okha
# Processing Record 15 of Set 4 | kirkland lake
# Processing Record 16 of Set 4 | villarrica
# Processing Record 17 of Set 4 | contamana
# Processing Record 18 of Set 4 | vostok
# Processing Record 19 of Set 4 | chake chake
# Processing Record 20 of Set 4 | clyde river
# Processing Record 21 of Set 4 | usinsk
# Processing Record 22 of Set 4 | dembi dolo
# Processing Record 23 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 4 | kavaratti
# Processing Record 25 of Set 4 | zvishavane
# Processing Record 26 of Set 4 | kisangani
# Processing Record 27 of Set 4 | brae
# Processing Record 28 of Set 4 | cherskiy
# Processing Record 29 of Set 4 | kitgum
# Processing Record 30 of Set 4 | cidreira
# Processing Record 31 of Set 4 | san carlos de bariloche
# Processing Record 32 of Set 4 | manavalakurichi
# Processing Record 33 of Set 4 | cumbitara
# Processing Record 34 of Set 4 | port elizabeth
# Processing Record 35 of Set 4 | pinar del rio
# Processing Record 36 of Set 4 | dalton
# Processing Record 37 of Set 4 | mantua
# Processing Record 38 of Set 4 | tarazona
# Processing Record 39 of Set 4 | hay river
# Processing Record 40 of Set 4 | shenjiamen
# Processing Record 41 of Set 4 | sitka
# Processing Record 42 of Set 4 | praia da vitoria
# Processing Record 43 of Set 4 | atuona
# Processing Record 44 of Set 4 | galesong
# Processing Record 45 of Set 4 | paamiut
# Processing Record 46 of Set 4 | nantucket
# Processing Record 47 of Set 4 | garowe
# Processing Record 48 of Set 4 | poopo
# Processing Record 49 of Set 4 | port alfred
# Processing Record 50 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 5 | biloela
# Processing Record 2 of Set 5 | gigmoto
# Processing Record 3 of Set 5 | tuatapere
# Processing Record 4 of Set 5 | lenoir city
# Processing Record 5 of Set 5 | moindou
# Processing Record 6 of Set 5 | puno
# Processing Record 7 of Set 5 | amurrio
# Processing Record 8 of Set 5 | atbasar
# Processing Record 9 of Set 5 | kon tum
# Processing Record 10 of Set 5 | lata
# Processing Record 11 of Set 5 | pochutla
# Processing Record 12 of Set 5 | chuy
# Processing Record 13 of Set 5 | kidal
# Processing Record 14 of Set 5 | port hardy
# Processing Record 15 of Set 5 | larsnes
# Processing Record 16 of Set 5 | mar del plata
# Processing Record 17 of Set 5 | raudeberg
# Processing Record 18 of Set 5 | berlevag
# Processing Record 19 of Set 5 | volot
# Processing Record 20 of Set 5 | tiksi
# Processing Record 21 of Set 5 | saskylakh
# Processing Record 22 of Set 5 | dikson
# Processing Record 23 of Set 5 | san patricio
# Processing Record 24 of Set 5 | new norfolk
# Processing Record 25 of Set 5 | leh
# Processing Record 26 of Set 5 | meulaboh
# Processing Record 27 of Set 5 | ushtobe
# Processing Record 28 of Set 5 | cerrito
# Processing Record 29 of Set 5 | salalah
# Processing Record 30 of Set 5 | krasnoselkup
# Processing Record 31 of Set 5 | vila franca do campo
# Processing Record 32 of Set 5 | andevoranto
# City not found. Skipping...
# Processing Record 33 of Set 5 | iqaluit
# Processing Record 34 of Set 5 | fortuna
# Processing Record 35 of Set 5 | luangwa
# Processing Record 36 of Set 5 | huarmey
# Processing Record 37 of Set 5 | brentwood
# Processing Record 38 of Set 5 | lebu
# Processing Record 39 of Set 5 | grand gaube
# Processing Record 40 of Set 5 | borovskoy
# Processing Record 41 of Set 5 | codrington
# Processing Record 42 of Set 5 | springbok
# Processing Record 43 of Set 5 | hede
# Processing Record 44 of Set 5 | sorland
# Processing Record 45 of Set 5 | tabas
# Processing Record 46 of Set 5 | vao
# Processing Record 47 of Set 5 | catalina
# Processing Record 48 of Set 5 | san pedro
# Processing Record 49 of Set 5 | rosarito
# Processing Record 50 of Set 5 | xai-xai
# Processing Record 1 of Set 6 | strezhevoy
# Processing Record 2 of Set 6 | itai
# Processing Record 3 of Set 6 | sao joao da barra
# Processing Record 4 of Set 6 | half moon bay
# Processing Record 5 of Set 6 | zhuanghe
# Processing Record 6 of Set 6 | fairbanks
# Processing Record 7 of Set 6 | jupanesti
# City not found. Skipping...
# Processing Record 8 of Set 6 | namatanai
# Processing Record 9 of Set 6 | gornopravdinsk
# Processing Record 10 of Set 6 | deputatskiy
# Processing Record 11 of Set 6 | santa cruz cabralia
# Processing Record 12 of Set 6 | cayenne
# Processing Record 13 of Set 6 | pontianak
# Processing Record 14 of Set 6 | dingle
# Processing Record 15 of Set 6 | sampit
# Processing Record 16 of Set 6 | ribeira grande
# Processing Record 17 of Set 6 | aklavik
# Processing Record 18 of Set 6 | caxito
# Processing Record 19 of Set 6 | nome
# Processing Record 20 of Set 6 | dibaya
# City not found. Skipping...
# Processing Record 21 of Set 6 | poykovskiy
# Processing Record 22 of Set 6 | ixtapa
# Processing Record 23 of Set 6 | tarbagatay
# Processing Record 24 of Set 6 | mpongwe
# Processing Record 25 of Set 6 | luderitz
# Processing Record 26 of Set 6 | macapa
# Processing Record 27 of Set 6 | jutai
# Processing Record 28 of Set 6 | pringsewu
# Processing Record 29 of Set 6 | mwene-ditu
# Processing Record 30 of Set 6 | mahebourg
# Processing Record 31 of Set 6 | xingyi
# Processing Record 32 of Set 6 | hami
# Processing Record 33 of Set 6 | duluth
# Processing Record 34 of Set 6 | nanyuki
# Processing Record 35 of Set 6 | almaznyy
# Processing Record 36 of Set 6 | rio grande
# Processing Record 37 of Set 6 | puerto vallarta
# Processing Record 38 of Set 6 | hashtrud
# Processing Record 39 of Set 6 | kamina
# Processing Record 40 of Set 6 | saint-leu
# Processing Record 41 of Set 6 | namibe
# Processing Record 42 of Set 6 | tanjong sepat
# City not found. Skipping...
# Processing Record 43 of Set 6 | yudong
# Processing Record 44 of Set 6 | banjar
# Processing Record 45 of Set 6 | harlingen
# Processing Record 46 of Set 6 | kruisfontein
# Processing Record 47 of Set 6 | partyzany
# Processing Record 48 of Set 6 | tilichiki
# Processing Record 49 of Set 6 | tual
# Processing Record 50 of Set 6 | bathsheba
# Processing Record 1 of Set 7 | nicoya
# Processing Record 2 of Set 7 | baykit
# Processing Record 3 of Set 7 | omagh
# Processing Record 4 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 5 of Set 7 | pisco
# Processing Record 6 of Set 7 | shaoguan
# Processing Record 7 of Set 7 | sola
# Processing Record 8 of Set 7 | yar-sale
# Processing Record 9 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 7 | miyako
# Processing Record 11 of Set 7 | sechura
# Processing Record 12 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 7 | myitkyina
# Processing Record 14 of Set 7 | burgeo
# Processing Record 15 of Set 7 | hue
# Processing Record 16 of Set 7 | rio verde de mato grosso
# Processing Record 17 of Set 7 | armstrong
# Processing Record 18 of Set 7 | kamaishi
# Processing Record 19 of Set 7 | saint-pierre
# Processing Record 20 of Set 7 | monroe
# Processing Record 21 of Set 7 | lingyuan
# Processing Record 22 of Set 7 | mattru
# Processing Record 23 of Set 7 | aluksne
# Processing Record 24 of Set 7 | mehriz
# Processing Record 25 of Set 7 | saquarema
# Processing Record 26 of Set 7 | puerto escondido
# Processing Record 27 of Set 7 | kamenka
# Processing Record 28 of Set 7 | caravelas
# Processing Record 29 of Set 7 | hirado
# Processing Record 30 of Set 7 | telimele
# Processing Record 31 of Set 7 | rezekne
# Processing Record 32 of Set 7 | cabedelo
# Processing Record 33 of Set 7 | sao filipe
# Processing Record 34 of Set 7 | omboue
# Processing Record 35 of Set 7 | dubbo
# Processing Record 36 of Set 7 | richards bay
# Processing Record 37 of Set 7 | havelock
# Processing Record 38 of Set 7 | hovd
# Processing Record 39 of Set 7 | husavik
# Processing Record 40 of Set 7 | katsuura
# Processing Record 41 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 7 | sakaiminato
# Processing Record 43 of Set 7 | nurota
# Processing Record 44 of Set 7 | kikwit
# Processing Record 45 of Set 7 | moron
# Processing Record 46 of Set 7 | pizhanka
# Processing Record 47 of Set 7 | pitkyaranta
# Processing Record 48 of Set 7 | gopichettipalaiyam
# City not found. Skipping...
# Processing Record 49 of Set 7 | talnakh
# Processing Record 50 of Set 7 | beloha
# Processing Record 1 of Set 8 | araguaina
# Processing Record 2 of Set 8 | ostersund
# Processing Record 3 of Set 8 | kars
# Processing Record 4 of Set 8 | neon karlovasion
# Processing Record 5 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 8 | mehamn
# Processing Record 7 of Set 8 | dali
# Processing Record 8 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 9 of Set 8 | tongliao
# Processing Record 10 of Set 8 | henties bay
# Processing Record 11 of Set 8 | rasuceni
# Processing Record 12 of Set 8 | buariki
# City not found. Skipping...
# Processing Record 13 of Set 8 | bilma
# Processing Record 14 of Set 8 | necochea
# Processing Record 15 of Set 8 | kavieng
# Processing Record 16 of Set 8 | trapani
# Processing Record 17 of Set 8 | tevaitoa
# Processing Record 18 of Set 8 | lorengau
# Processing Record 19 of Set 8 | excelsior springs
# Processing Record 20 of Set 8 | utmanzai
# Processing Record 21 of Set 8 | saint-denis
# Processing Record 22 of Set 8 | marand
# Processing Record 23 of Set 8 | taybad
# Processing Record 24 of Set 8 | jaisinghnagar
# Processing Record 25 of Set 8 | esteio
# Processing Record 26 of Set 8 | jujuy
# City not found. Skipping...
# Processing Record 27 of Set 8 | kismayo
# Processing Record 28 of Set 8 | haines junction
# Processing Record 29 of Set 8 | aflao
# Processing Record 30 of Set 8 | abeche
# Processing Record 31 of Set 8 | zhigansk
# Processing Record 32 of Set 8 | wanganui
# Processing Record 33 of Set 8 | gravdal
# Processing Record 34 of Set 8 | torbay
# Processing Record 35 of Set 8 | hualmay
# Processing Record 36 of Set 8 | itupiranga
# Processing Record 37 of Set 8 | xam nua
# Processing Record 38 of Set 8 | tecpan
# Processing Record 39 of Set 8 | east brainerd
# Processing Record 40 of Set 8 | north bend
# Processing Record 41 of Set 8 | iracoubo
# Processing Record 42 of Set 8 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 43 of Set 8 | nanakuli
# Processing Record 44 of Set 8 | lazaro cardenas
# Processing Record 45 of Set 8 | tairua
# Processing Record 46 of Set 8 | darhan
# Processing Record 47 of Set 8 | mishan
# Processing Record 48 of Set 8 | tiarei
# Processing Record 49 of Set 8 | oktyabrskiy
# Processing Record 50 of Set 8 | sao gabriel da cachoeira
# Processing Record 1 of Set 9 | laguna
# Processing Record 2 of Set 9 | santa fe
# Processing Record 3 of Set 9 | guacimo
# Processing Record 4 of Set 9 | sao jose da coroa grande
# Processing Record 5 of Set 9 | elat
# Processing Record 6 of Set 9 | mollendo
# Processing Record 7 of Set 9 | kiyasovo
# Processing Record 8 of Set 9 | ushirombo
# Processing Record 9 of Set 9 | cambridge
# Processing Record 10 of Set 9 | sambava
# Processing Record 11 of Set 9 | broome
# Processing Record 12 of Set 9 | nara
# Processing Record 13 of Set 9 | makakilo city
# Processing Record 14 of Set 9 | teguldet
# Processing Record 15 of Set 9 | agirish
# Processing Record 16 of Set 9 | sovetskaya
# Processing Record 17 of Set 9 | tasiilaq
# Processing Record 18 of Set 9 | van
# Processing Record 19 of Set 9 | nampa
# Processing Record 20 of Set 9 | xinzhi
# Processing Record 21 of Set 9 | jumla
# Processing Record 22 of Set 9 | brandon
# Processing Record 23 of Set 9 | prince rupert
# Processing Record 24 of Set 9 | fare
# Processing Record 25 of Set 9 | yaan
# Processing Record 26 of Set 9 | mount gambier
# Processing Record 27 of Set 9 | smithers
# Processing Record 28 of Set 9 | bilibino
# Processing Record 29 of Set 9 | sandy bay
# Processing Record 30 of Set 9 | carbonia
# Processing Record 31 of Set 9 | pho chai
# Processing Record 32 of Set 9 | istanbul
# Processing Record 33 of Set 9 | jinka
# Processing Record 34 of Set 9 | praia
# Processing Record 35 of Set 9 | ponta delgada
# Processing Record 36 of Set 9 | gwanda
# Processing Record 37 of Set 9 | revda
# Processing Record 38 of Set 9 | jomalig
# City not found. Skipping...
# Processing Record 39 of Set 9 | ben tre
# Processing Record 40 of Set 9 | jackson
# Processing Record 41 of Set 9 | santa vitoria do palmar
# Processing Record 42 of Set 9 | dandong
# Processing Record 43 of Set 9 | saldanha
# Processing Record 44 of Set 9 | beeville
# Processing Record 45 of Set 9 | komsomolskiy
# Processing Record 46 of Set 9 | kirakira
# Processing Record 47 of Set 9 | yerbogachen
# Processing Record 48 of Set 9 | athens
# Processing Record 49 of Set 9 | alekseyevsk
# Processing Record 50 of Set 9 | vilyuysk
# Processing Record 1 of Set 10 | bolivar
# Processing Record 2 of Set 10 | honiara
# Processing Record 3 of Set 10 | bajil
# Processing Record 4 of Set 10 | whittlesea
# Processing Record 5 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 6 of Set 10 | felanitx
# Processing Record 7 of Set 10 | catuday
# Processing Record 8 of Set 10 | atar
# Processing Record 9 of Set 10 | westport
# Processing Record 10 of Set 10 | devonport
# Processing Record 11 of Set 10 | lavrentiya
# Processing Record 12 of Set 10 | isangel
# Processing Record 13 of Set 10 | dharchula
# Processing Record 14 of Set 10 | gangotri
# City not found. Skipping...
# Processing Record 15 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 10 | andenes
# Processing Record 17 of Set 10 | filadelfia
# Processing Record 18 of Set 10 | ankara
# Processing Record 19 of Set 10 | shaunavon
# Processing Record 20 of Set 10 | touros
# Processing Record 21 of Set 10 | nandgaon
# Processing Record 22 of Set 10 | san andres
# Processing Record 23 of Set 10 | rovnoye
# Processing Record 24 of Set 10 | yarada
# Processing Record 25 of Set 10 | pitimbu
# Processing Record 26 of Set 10 | zhenlai
# Processing Record 27 of Set 10 | sabha
# Processing Record 28 of Set 10 | karratha
# Processing Record 29 of Set 10 | taveta
# Processing Record 30 of Set 10 | teya
# Processing Record 31 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 32 of Set 10 | inhambane
# Processing Record 33 of Set 10 | dzilam gonzalez
# Processing Record 34 of Set 10 | lompoc
# Processing Record 35 of Set 10 | ahome
# Processing Record 36 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 37 of Set 10 | sfantu gheorghe
# Processing Record 38 of Set 10 | fort nelson
# Processing Record 39 of Set 10 | banes
# Processing Record 40 of Set 10 | silver city
# Processing Record 41 of Set 10 | tukrah
# Processing Record 42 of Set 10 | yulara
# Processing Record 43 of Set 10 | alyangula
# Processing Record 44 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 45 of Set 10 | saint anthony
# Processing Record 46 of Set 10 | mayo
# Processing Record 47 of Set 10 | mairang
# Processing Record 48 of Set 10 | namtsy
# Processing Record 49 of Set 10 | athabasca
# Processing Record 50 of Set 10 | udachnyy
# Processing Record 1 of Set 11 | gladstone
# Processing Record 2 of Set 11 | ostrovnoy
# Processing Record 3 of Set 11 | cockburn town
# Processing Record 4 of Set 11 | ozinki
# Processing Record 5 of Set 11 | kinsale
# Processing Record 6 of Set 11 | krieglach
# Processing Record 7 of Set 11 | saint-louis
# Processing Record 8 of Set 11 | baruun-urt
# Processing Record 9 of Set 11 | valparaiso
# Processing Record 10 of Set 11 | hirara
# Processing Record 11 of Set 11 | cumana
# Processing Record 12 of Set 11 | kosh-agach
# Processing Record 13 of Set 11 | kasongo-lunda
# Processing Record 14 of Set 11 | mendi
# Processing Record 15 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 16 of Set 11 | barmer
# Processing Record 17 of Set 11 | mocuba
# Processing Record 18 of Set 11 | chapais
# Processing Record 19 of Set 11 | paldiski
# Processing Record 20 of Set 11 | nago
# Processing Record 21 of Set 11 | montepuez
# Processing Record 22 of Set 11 | shingu
# Processing Record 23 of Set 11 | ziro
# Processing Record 24 of Set 11 | cabo san lucas
# Processing Record 25 of Set 11 | nosy varika
# Processing Record 26 of Set 11 | okmulgee
# Processing Record 27 of Set 11 | aksu
# Processing Record 28 of Set 11 | alofi
# Processing Record 29 of Set 11 | presidencia roque saenz pena
# Processing Record 30 of Set 11 | burns lake
# Processing Record 31 of Set 11 | santa isabel
# Processing Record 32 of Set 11 | tamandare
# Processing Record 33 of Set 11 | logan lake
# Processing Record 34 of Set 11 | murphy
# Processing Record 35 of Set 11 | jalu
# Processing Record 36 of Set 11 | walvis bay
# Processing Record 37 of Set 11 | zhezkazgan
# Processing Record 38 of Set 11 | hit
# Processing Record 39 of Set 11 | kalabo
# Processing Record 40 of Set 11 | fallon
# Processing Record 41 of Set 11 | flinders
# Processing Record 42 of Set 11 | plouzane
# Processing Record 43 of Set 11 | nushki
# Processing Record 44 of Set 11 | saint-augustin
# Processing Record 45 of Set 11 | morondava
# Processing Record 46 of Set 11 | dillon
# Processing Record 47 of Set 11 | marystown
# Processing Record 48 of Set 11 | barabai
# Processing Record 49 of Set 11 | ulladulla
# Processing Record 50 of Set 11 | brownsville
# Processing Record 1 of Set 12 | pascagoula
# Processing Record 2 of Set 12 | barranca
# Processing Record 3 of Set 12 | srednekolymsk
# Processing Record 4 of Set 12 | borama
# City not found. Skipping...
# Processing Record 5 of Set 12 | san isidro
# Processing Record 6 of Set 12 | dunedin
# Processing Record 7 of Set 12 | vila velha
# Processing Record 8 of Set 12 | buribay
# Processing Record 9 of Set 12 | dongsheng
# Processing Record 10 of Set 12 | pilar
# Processing Record 11 of Set 12 | woodward
# Processing Record 12 of Set 12 | belle fourche
# Processing Record 13 of Set 12 | san cristobal
# Processing Record 14 of Set 12 | sovetskiy
# Processing Record 15 of Set 12 | san policarpo
# Processing Record 16 of Set 12 | semey
# Processing Record 17 of Set 12 | sept-iles
# Processing Record 18 of Set 12 | lyngseidet
# Processing Record 19 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 12 | zabolotovka
# Processing Record 21 of Set 12 | pandharpur
# Processing Record 22 of Set 12 | iwaki
# Processing Record 23 of Set 12 | kahului
# Processing Record 24 of Set 12 | knysna
# Processing Record 25 of Set 12 | karlskrona
# Processing Record 26 of Set 12 | lewisporte
# Processing Record 27 of Set 12 | salme
# Processing Record 28 of Set 12 | burica
# City not found. Skipping...
# Processing Record 29 of Set 12 | canutama
# Processing Record 30 of Set 12 | falam
# Processing Record 31 of Set 12 | shizunai
# Processing Record 32 of Set 12 | tiznit
# Processing Record 33 of Set 12 | erdenet
# Processing Record 34 of Set 12 | markala
# Processing Record 35 of Set 12 | pervoye maya
# Processing Record 36 of Set 12 | asayita
# City not found. Skipping...
# Processing Record 37 of Set 12 | mae hong son
# Processing Record 38 of Set 12 | champerico
# Processing Record 39 of Set 12 | aosta
# Processing Record 40 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 12 | aguimes
# Processing Record 42 of Set 12 | taoudenni
# Processing Record 43 of Set 12 | vulcan
# Processing Record 44 of Set 12 | mugur-aksy
# Processing Record 45 of Set 12 | quelimane
# Processing Record 46 of Set 12 | nouadhibou
# Processing Record 47 of Set 12 | miri
# Processing Record 48 of Set 12 | ashqelon
# Processing Record 49 of Set 12 | tucuman
# Processing Record 50 of Set 12 | bandarbeyla
# Processing Record 1 of Set 13 | slave lake
# Processing Record 2 of Set 13 | igrim
# Processing Record 3 of Set 13 | mecca
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 555

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0     Ahipara      NZ -35.17  173.17     52.84        84           0
# 1     Rikitea      PF -23.12 -134.97     70.41        69         100
# 2        Hofn      IS  64.25  -15.21     53.60        81          75
# 3  Bredasdorp      ZA -34.53   20.04     53.60        62           0
# 4  Kaitangata      NZ -46.28  169.85     42.01        74          72
#
#    Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0        7.07           clear sky            0.0              0
# 1       13.60     overcast clouds            0.0              0
# 2        2.24       broken clouds            0.0              0
# 3        9.17           clear sky            0.0              0
# 4       11.01       broken clouds            0.0              0

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
